# %% [markdown]
# # Taylor Swift Youtube Channel Analysis

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd 
import requests
import json
from datetime import datetime
import csv

# %% [markdown]
# ## Step 0: Crawl data from YouTube

# %%
api_key = "AIzaSyBTNViA-4U8Svz6612IBNqRgSfRcfx2Xiw" # Youtube API key
channel_id = "UCqECaJ8Gagnn7YCbPEzWH6g" # Tailor Swift Channel
base_url = 'https://www.googleapis.com/youtube/v3/'

# %% [markdown]
# ### Get Channel information

# %%
channel_url = f'{base_url}channels?part=statistics&key={api_key}&id={channel_id}'
channel_info = requests.get(channel_url)
json_data = json.loads(channel_info.text)
json_data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'MDFbK13kVceS0ATdekXhX2FQduc',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'hq0u3EO7rDqfNgpoCuKj1f6Jzgg',
#    'id': 'UCqECaJ8Gagnn7YCbPEzWH6g',
#    'statistics': {'viewCount': '36171320990',
#     'subscriberCount': '59600000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '271'}}]}

# %%
channel_subscribers = int(json_data['items'][0]['statistics']['subscriberCount'])
channel_videos = int(json_data['items'][0]['statistics']['videoCount'])
channel_views = int(json_data['items'][0]['statistics']['viewCount'])

print(f'Total subscribers: {channel_subscribers}')
print(f'Total videos: {channel_videos}')
print(f'Total views: {channel_views}')
# Out:
# Total subscribers: 59600000
# Total videos: 271
# Total views: 36171320990

# %% [markdown]
# ### Get channel videos details

# %%
details_url = f'{base_url}channels?part=contentDetails&key={api_key}&id={channel_id}'
details_response = requests.get(details_url)
details_data = json.loads(details_response.text)
uploads_playlist_id = details_data['items'][0]['contentDetails']['relatedPlaylists']['uploads']

details_data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'h4AJNYKjhqKeKyyVogOFTGPJlwQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'Kf9IDojpZE-9uW6NGeZTes9qvN8',
#    'id': 'UCqECaJ8Gagnn7YCbPEzWH6g',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUqECaJ8Gagnn7YCbPEzWH6g'}}}]}

# %%
videos = {
    'id' : [],
    'published_date' : [],
    'title' : [],
    'description' : [],
    'likes' : [],
    'views' : [],
    'comments' : []
}

# %%
next_page_token = None

while True:
    playlist_url = f'{base_url}playlistItems?part=snippet&playlistId={uploads_playlist_id}&maxResults=50&key={api_key}'

    if next_page_token is not None:
        playlist_url += f'&pageToken={next_page_token}'
        
    playlist_response = requests.get(playlist_url)
    playlist_data = json.loads(playlist_response.text)

    video_ids = [item['snippet']['resourceId']['videoId'] for item in playlist_data['items']]
    videos_url = f'{base_url}videos?part=snippet,statistics&id={",".join(video_ids)}&key={api_key}'
    video_response = requests.get(videos_url)
    videos_data = json.loads(video_response.text)
    
    for item in videos_data['items']:
        videos['id'].append(item['id'])
        videos['published_date'].append(datetime.fromisoformat(item['snippet']['publishedAt'].replace('Z', '+00:00')).strftime('%Y-%m-%d'))
        videos['title'].append(item['snippet']['title'])
        videos['description'].append(item['snippet']['description'])
        videos['likes'].append(item['statistics'].get('likeCount', 'N/A'))
        videos['views'].append(item['statistics'].get('viewCount', 'N/A'))
        videos['comments'].append(item['statistics'].get('commentCount', 'N/A'))
    
    next_page_token = playlist_data.get('nextPageToken')
    if not next_page_token:
        break

videos
# Out:
# {'id': ['PQTA-EVc5DI',
#   'HZIg5sQrPAM',
#   '0GQ_QeZxdzo',
#   'KJXP13hqf2I',
#   'ZwlBxvnH-So',
#   'F0TUVujmtxY',
#   'AtDCWnV_Vzo',
#   'BpkmUfv1I4Q',
#   '56TZ3B8Qxsk',
#   '2hBLC7E8v3A',
#   'iMMUAd66vxo',
#   'vOZFiX6hDXQ',
#   'uEssK8o3jKg',
#   'bAi80EylyXQ',
#   'iY6Qhlua8Zw',
#   '_PsBoqNwYo4',
#   'wRKXAAV6jh4',
#   'RQMz4JDbtmI',
#   'w-FkV0EM_CU',
#   'oaBJlKXBvjk',
#   'gOtOWeD9YJk',
#   'fcVUbmdQfaE',
#   'i8_w_m6HLJ0',
#   'OKWfv-x2rdU',
#   'OOYlWF6V8t8',
#   'Mxxswu7V1Us',
#   'EVbtjaWXQVg',
#   'FQyEZZPbOb0',
#   'SBGdvxi2JmU',
#   'GZ4vaTRn0HU',
#   'U2W173hRfyA',
#   'O3wlMR0y4a4',
#   'Atdzfj8LcuY',
#   'CCUr2pNJft4',
#   'HzsQHfBA3MY',
#   'q3zqJs7JUCQ',
#   '4wOsiM2T_xc',
#   '6HIA7ouBfGY',
#   '0EKbEP2L32M',
#   '0hYY86DmqPY',
#   'GhXsnvmUQrg',
#   'b7kmP1fsGg8',
#   'QBllgPHa8aQ',
#   '7yRXgL7SaV0',
#   'RlDSGLHcZy0',
#   'ilkvTXfv2TY',
#   'pQq9eP5OFhw',
#   'zz9YgUoisOA',
#   'vaRGgiGfsw4',
#   'tNxUxm3-658',
#   'yF4ulRTCn44',
#   'vtW_4j7SsZk',
#   'lUvBk4owRNU',
#   'rnwD7veCoFQ',
#   'gp1MR2WAAXY',
#   'gir8BEqAutk',
#   'mvVBuG4IOW4',
#   'qrxsceexTBw',
#   '_Usd5X5XJXM',
#   'ZGBPKYbzSXs',
#   'FsGdznlfE2U',
#   'AppsjTInqiw',
#   'M7ySK0keirY',
#   'JhICcmiIE80',
#   'C-z-IckrQK8',
#   '89aQIli8aVU',
#   '2JgvVfOfoWI',
#   '3-BcH7KowGE',
#   '0jTGzm-6cYE',
#   'xB-RZqcoIgo',
#   'GBb8vC0DeXY',
#   'KzNLM4nmRak',
#   'US0OipWyYro',
#   'KudedLV0tP0',
#   '0FZULHCZKBc',
#   'okPrv0o_7GQ',
#   'lVkKLf4DCn8',
#   'vO6JqQpJboY',
#   'maEVfpxDB8k',
#   'idWma942CUI',
#   'oxNLRqMJMZk',
#   'hMPK2vNXr-E',
#   'qc2Z-OX9wnc',
#   'osmzwWw4RYM',
#   'UlFrV5GJA_4',
#   'pRhWAXg4xek',
#   'igIfiqqVHtA',
#   'jOD86iMAEY0',
#   'V80A8qN4fR8',
#   'IYqgVYjN3Go',
#   'EH70M5OeS4o',
#   'F5TMU6916U8',
#   'N-FYySSy0rM',
#   'Fn0er7H1Dm0',
#   'PH8Uc0Z_KRY',
#   'JlZnvyBqceY',
#   '8AR1dKawCi8',
#   '4cC6fw8EqWU',
#   '6-x1AlDudZw',
#   'yJTfs8YS2w0',
#   'XzOvgu3GPwY',
#   '_f4yoKJL7IQ',
#   'Hoi-PI8QpTU',
#   '2CnUYMmEHrs',
#   'YvyeAwoZ76w',
#   'anqxTwGE_nQ',
#   'kE31ShDEOwg',
#   'nfFujEdM0_E',
#   'ZZtamrXjB_w',
#   'pCH19_8E4Hw',
#   '6DdAzVDVBpw',
#   'h8DLofLM7No',
#   'HqDZxtMIx0M',
#   'M0Ku_op-LXI',
#   'nF4Jc9sPPug',
#   'ijjGqwdXa1c',
#   'eSLO-HpSWD0',
#   'uybMJ8cSWtA',
#   'Cd3v_pRgOp8',
#   'NbS4s_6jYTg',
#   'T1d9PiRAJNM',
#   'IVQqOzFKN2M',
#   'uhjx7FemU6o',
#   'lM1P2JwZ5jE',
#   'yJ_GML26Xk4',
#   'b7QlX3yR2xs',
#   'ycE7bUq3-2k',
#   'ySZGZrcqvr4',
#   'xTXsKMXUi7w',
#   'xxrf_QBD5DE',
#   'lvHZjvIyqsk',
#   'mkR_Qwix4Ho',
#   'rn0brgg2BpI',
#   'iFX6_9h7th0',
#   'rg18Kf4en2o',
#   'l8Tps3PITx4',
#   'X0Jti9F-oQA',
#   'XzKSPRqFg9E',
#   'Y2a73EvnZ4s',
#   'Uoey4W_3bos',
#   'Tmz1lz0zcLQ',
#   'XqN2qFvY64U',
#   'B-MfwP_RmHY',
#   'Odh9ddPUkEY',
#   '7Gbg6Z70J7E',
#   '-qee6dFKlw4',
#   'U1IqinpmpQE',
#   '9Wx2It8SbLs',
#   'b1kbLwvqugk',
#   'Jo-8VaRU4ok',
#   '3fUS9GAMxv4',
#   'egxyRSb_XtI',
#   '3Q94kA7llGw',
#   'mvxQYPR4lmU',
#   'mCWRjuhRRYg',
#   'gRo0ZtgB2io',
#   'r0yq_yXFQhg',
#   'pPrdGE4w9ZM',
#   'UDzPTerKZn8',
#   '5UMCrq-bBCg',
#   'nJr_8l0AEWE',
#   'tollGa3S0o8',
#   'sRxrwjOtIag',
#   'lPvcwgEuKTg',
#   'R_rUYuFtNO4',
#   'flv8AEWrRMI',
#   'u1D1AgDfreg',
#   'zJFcr1KyFqE',
#   'w1AV_35zVwU',
#   'TqAollrUJdA',
#   'OhJ-S9Nrh7Q',
#   'rVuyi-dPMIc',
#   'm3fWCRvz5JA',
#   'kdiBc40gW7s',
#   'pCH4QrSx2Jg',
#   'cVaG6adE2mA',
#   'hHWOAUjnmjQ',
#   'jQfB4Gahi3I',
#   'dXNZaHuKWNA',
#   'eMcMbWl0fDk',
#   'TkAomsYFsJw',
#   'UNckfN9upqo',
#   'VN55tCajFYg',
#   'S4PuN-IWi2g',
#   'LmXn6BU16e0',
#   'PReSQYTFvcs',
#   '9boiT64sm0Q',
#   'AccGdO5XeZY',
#   'BZ-rLBkUZf4',
#   'D3mJe28un4M',
#   '3pj39qZZYoQ',
#   '4LtQxA_ooLk',
#   '9OQBDdNHmXo',
#   '-mrC5tRkxrY',
#   't0Yf43ONyNo',
#   'CUr_UwUUXzU',
#   'y8tF0yRl8-w',
#   'n0cde-Km05o',
#   'yuFuwXd-B9E',
#   'seU5y5EgIwk',
#   'qsUK-BG5OQQ',
#   'xSWVPqnKcXQ',
#   'jwWR1cQTKyw',
#   'vUHDR6Rg3Y4',
#   'cwFbq-70EwE',
#   'tMhiHrL7rPE',
#   'RcGowZ26sE0',
#   'rLCol1C3ouc',
#   'vwp8Ur6tO-8',
#   'dHdAN4FXzmc',
#   'ePjcjLRHPOo',
#   'T-41vMWQTUA',
#   'IsCik8wznlU',
#   'KZeI9I875Ig',
#   '7lLigiVgJsE',
#   'DlexmDDSDZ0',
#   '425n1NoRtgA',
#   'DNaSlUYIXBg',
#   '8bNlGwnEUAs',
#   '9-rKvhsjwKU',
#   'aOa6D6ku3dM',
#   'rFjJs6ZjPe8',
#   'XKaMUm7YwZc',
#   'FeTHyZJvozc',
#   'Uzii44SDYFA',
#   'aXzVF3XeS8M',
#   'Ur_wAcYDnuA',
#   '1iRbIYkccgw',
#   'iTNZ-OzBoBo',
#   'H9rBt-8jiBE',
#   'sViZJopFdYg',
#   'qybUgW7eoZQ',
#   '7XLW5CvDQ7E',
#   '3CUM7Z3TSmY',
#   'CYHt7_RANiY',
#   'qAGef4MdPdE',
#   'zI4DS5GmQWE',
#   'wMpqCRF7TKg',
#   'ukxEKY_7MOc',
#   'YPlNBb6I8qU',
#   'tP4TTgt4nb0',
#   'rqQHa2HcGtM',
#   'IEPomqor2A8',
#   'RsEZmictANA',
#   'hP6QpMeSG6s',
#   'c_p_TBaHvos',
#   '9nIOx-ezlzA',
#   'WuvhOD-mP8M',
#   'Pz-f9mM3Ms8',
#   'EXLgZZE072g',
#   '7EvwIw4gIyk',
#   'AIFnKqIeEdY',
#   'o5SQIECedTY',
#   'jgdFUoZzCI0',
#   'orXAg5dIMa8',
#   'tOHcAc3r2kw',
#   'GPQdWYNi8Wc',
#   'i50QUXDeC80',
#   'osdoLjUNFnA',
#   'ryLGxpjwAhM',
#   'pEY-GPsru_E',
#   'nn_0zPAfyo8',
#   'zLSUp53y-HQ',
#   'HpxX4ZE4KWE',
#   'K-a8s8OLBSE',
#   'OWbDJFtHl3w',
#   '9bdLTPNrlEg',
#   'KaM1bCuG4xo',
#   'MLV2SJKWk4M',
#   'OuFnpmGwg5k',
#   '6TAPqXkZW_I',
#   'KsZ6tROaVOQ',
#   '6DP4q_1EgQQ',
#   'DUnDkI7l9LQ',
#   '2s5xdY6MCeI',
#   'Vgt1d3eAm7A',
#   'rqsmrSyLTNM',
#   'JSD4XCBWzvs',
#   'd_2WyBcFbFY',
#   'DIMDgq_MYJs',
#   'Uxg-ivPGusQ',
#   '3xGvCApIEQY',
#   'a4iTHPwioEc',
#   'IQL1vIP9sos',
#   'mxtUnuldKgc',
#   'a5gXfaAFPOM',
#   'AqAJLh9wuZ0',
#   'F3aXpa1rQEY',
#   'tbEekLA7J3Y',
#   'GJU-S1t2r1M',
#   '40RsbcFRwNA',
#   'O2Irnn7F1PM',
#   'hNHBVaFueYw',
#   'mN3rDTAdM2o',
#   'Ozk8xq0Lp1g',
#   'SVY8I46dkb0',
#   'KmT4Y8w1nho',
#   'RGJFqm1BnP4',
#   'trIjpVH8h88',
#   'b5Zay_Hd_7Q',
#   'kjD3LoXp-Pw',
#   'dmipFjOtMA8',
#   'hKcEdTPOGGw',
#   'pHoHDNxay3A',
#   'u9raS7-NisU',
#   'eaP1VswBF28',
#   'ic8j13piAhQ',
#   'p1cEvNn88jM',
#   'Kwf7P2GNAVw',
#   'tMoW5G5LU08',
#   'GTEFSuFfgnU',
#   'VikHHWrgb4Y',
#   'VsKoOH6DVys',
#   '8zdg-pDF10g',
#   '2d1wKn-oJnA',
#   'acQXa5ArHIk',
#   '8HxbqAsppwU',
#   'gRIWxlehJVg',
#   'iyYhqYELWtA',
#   'UY3UfH-ittk',
#   '1qwxqyac0Z8',
#   'dDO6HnY7h24',
#   '-BjZmE2gtdo',
#   'cvUAzpn48xA',
#   'PWdT2ONbJbc',
#   '8KpKc3C9V3w',
#   'SYd0pYqOJqA',
#   's4MN_hGvTCA',
#   '6MLzSp0OJL0',
#   'Dkk9gvTmCXY',
#   'GWtfOHBF1_w',
#   'MA0HQG9J9Yk',
#   '_zUCMfYkgj0',
#   'bqOfdv9i4sE',
#   'S--WI8PUVVo',
#   'lj2mZ8zDToY',
#   'MUf1ili4Zew',
#   'FuXNumBwDOM',
#   'HIb_TlK2HAI',
#   'RamgJyJsep4',
#   'MBR2kxt7RK8',
#   'aoYhTov8jsY',
#   'RMW3fAructY',
#   'zGSneb3McDo',
#   'sEr7bAtZ8rY',
#   'tCXGJQYZ9JA',
#   'VA7Y_Psp5l4',
#   'dfnCAmr569k',
#   'MvIwx0JThsk',
#   '66kn6Dcr12E',
#   'GZeza5xTeuM',
#   'oWVYzCPs3nE',
#   'eQVhAN7-IAw',
#   'kGOmPmILndU',
#   'V54CEElTF_U',
#   'wIft-t-MQuE',
#   'GU5_g8Tmiv8',
#   'EUoe7cf0HYw',
#   'np4Nw0tBun8',
#   '71QPEkD9PhM',
#   'e7HLU5-0VU4',
#   'jJeK0p1LanY',
#   'BKCmxyohzww',
#   'XF_ARz7jTUw',
#   'T62maKYX9tU',
#   '3tmd-ClpJxA',
#   'iM_j8_AZJW4',
#   '3K0RzZGpyds',
#   'J37Pitvp7RI',
#   'fJBFvNiJ4Kw',
#   'dwdtzwua2pY',
#   'QIUWI7dfnC0',
#   'OsJ5RyWpY5w',
#   '7F37r50VUTQ',
#   'wyK7YuwUWsU',
#   'TXJlB9riS1Y',
#   'p1Zt47V3pPw',
#   'OGDkg3QiJmk',
#   'JLf9q36UsBk',
#   'IdneKLhsWOQ',
#   'QcIy9NiNbmo',
#   'bKBJhghRfEk',
#   'cM2CXMcG5w8',
#   '-CmadmM5cOk',
#   'j3yyF31jbKo',
#   'BxZi6jC2JAI',
#   'e-ORhEE9VVg',
#   'JggOSZFlk0U',
#   '81doBkpkdJQ',
#   'xVKTOX3vMKM',
#   'EKnl7STzSMU',
#   'DqZOcABIgTk',
#   'M-M5SW8QvmY',
#   's8h0tZy0HqA',
#   'AoYtgGHfsG4',
#   'bs5SZOHowHI',
#   '70Ps-GzbSfw',
#   'vMWpIfxvnWo',
#   'TEpTNFHHjNg',
#   'kY-_D-IptZE',
#   'zdYy6-P_ggQ',
#   '1D5E5KLkfsI',
#   'nfWlot6h_JM',
#   'J1LMp-jEH_k',
#   'UfRqjF_8IqQ',
#   'kpzwfS5x068',
#   'QuijXg8wm28',
#   'DJXfSaOJXOQ',
#   'SvEbXNgvXWY',
#   'FTA4kzsTmxc',
#   '6wEVDvnqQOM',
#   'Ac7wMLgLtpY',
#   '41Zxe-tqjoE',
#   'y9yIBAmBDtk',
#   'EuT6nQvdcpo',
#   'C2giKOnk588',
#   'y7CsaOF3S5c',
#   'xmauy4h3rPg',
#   'Zlot0i3Zykw',
#   'YUSPwqd4674',
#   'LGA54hn8uwU',
#   'YfPfgZjhH1w',
#   'w1oM3kQpXRo',
#   '1hdDXzS63SY',
#   'JgkCFCOAn48',
#   'GDdVOpZkqRI',
#   'NZnRUnOQZWU',
#   '3H21433WdtU',
#   'Nx-5bHeC6xo',
#   'ueZmiOaDDlU',
#   'AgFeZr5ptV8',
#   'rghH6QlT5a0',
#   'jinbX0hwYOo',
#   'sIjKXPXjVxU',
#   'LyoTb3fxEnU',
#   '2obMo7y-rvA',
#   'vNoKguSdy4Y',
#   'OZJdxFEdjSU',
#   'BktS1hkMx_k',
#   'gQ0pP2z9niw',
#   'tvnGBYMe9gM',
#   'RQuY8kERaU0',
#   'cQ5tlnGg4wc',
#   'yfWgXcrNQIw',
#   'qbx_wdqaeV0',
#   'dgzN0Puq_hE',
#   '75NpXm04S1I',
#   'oo1CoPXIOuI',
#   'Rcex4Nw6Z9U',
#   '5FODVFJZlTg',
#   'Eo2D8Ez3WAo',
#   'FNWq-pr5ON8',
#   'XdalCja4TK8',
#   'YcuEHj-Nr58',
#   'ehLp0cjqkRk',
#   'sWgxCBXn2Y0',
#   'YoJj-5nAGpM',
#   'TGslPGte8Mw',
#   'TfjfzDIAIGE',
#   'YszERgNNKnc',
#   'yBHlFJ9waVo',
#   'k2zfi4gLekU',
#   'cMPEd8m79Hw',
#   'KNKa1to1v6o',
#   '1vj3YhYrULo',
#   'eocfbbyIUn8',
#   'WA4iX5D9Z64',
#   '6OPPGOl7ctE',
#   'gcMn_Eu-XTE',
#   'P6gFma4H7fA',
#   'I4TIvOCa3t8',
#   'weQBrpLffrA',
#   '8hsVICl7d8k',
#   'LkkY2iaylmI',
#   'tBEFMmkgu7s',
#   'FvodYNcH13Q',
#   'dLfkQNnzh2o',
#   'RzhAS_GnJIc',
#   'xDJLsPd6NdY',
#   'IdMI-HCO5QY',
#   'QvNW_z1Y7Ls',
#   'wIvJI6mF1ME',
#   'yHqjZUxaigo',
#   '7D6-_twz7YE',
#   '0Ot5C6O-KfA',
#   'HsLl-IL9c7E',
#   'gPJ8PFeq9Xw',
#   'Y89k5sfHBaw',
#   'h6CRgcouLuU',
#   '_zyYtE9di9A',
#   'AtHsg4USz8g',
#   'beGv3NTnduo',
#   'LZ34LlaIk88',
#   'O0Mnebw_TJc',
#   'lZNJnOrwDTQ',
#   'GSvyRVw366k',
#   'xIoApJgIw8U',
#   'woiScNulLyE',
#   '-CICulOcBQE',
#   'KFoOCZeKgzQ',
#   'urcHObkMCBE',
#   'OOPFMrF7v4Q',
#   'z___7lkxS0I',
#   'AcGbuveDwTg',
#   '_9RWI5JBew0',
#   'oKar-tF__ac',
#   'nN6VR92V70M',
#   'jYa1eI1hpDE',
#   've_o2kq4_jY',
#   'Zmv26eqduSg',
#   '9wXlz0f-2Zo',
#   'CpwF5fw6dE0',
#   'fTFcFeQOeLo',
#   'dlBQSxDuy2I',
#   'rx86WwyoI7g',
#   '-0uRcwk818Y',
#   'KWPrDngWZSQ',
#   '91EDAPQLsXc',
#   'LSjPFdoeDD8',
#   'jkin5pRLrQg',
#   'QUwxKWT6m7U',
#   'ZMt6TFO0zn4',
#   'zudLJdajX5Y',
#   '4wUPASp2hfY',
#   'xcLIGAIkztc',
#   'mNLVMDF9mUo',
#   'vio0RidOMUM',
#   '5jKcG86bNRs',
#   'QQVHNOxYv5E',
#   'XPBwXKgDTdE',
#   'w7p_BCIX-rw',
#   'IgZY0frgysw',
#   'uhHMWLjL77U',
#   'PVtlDvh74H8',
#   '37Pc4cjk9pY',
#   'Uo6HuSCBZu4',
#   'mxBSpHji2oo',
#   'U3yPyVFKGG8',
#   'VhFFAQuAUqo',
#   'ptSjNWnzpjg',
#   'Pb-K2tXWK4w',
#   'wzLhAZn_JMk',
#   'GVKuFZhB1e8',
#   'SnN7kIqDgz0',
#   'x2hRdQnbzKQ',
#   'Y3eRmLTN7FQ',
#   'Jb2stN7kH28',
#   'GkD20ajVxnY',
#   'xKCek6_dB0M',
#   'D1Xr-JFLxik',
#   'VuNIsY6JdUw',
#   '8xg3vE8Ie_E',
#   'l4_6eQm7RTQ',
#   'B1jYllE0T-k',
#   'AlTfYj7q5gQ',
#   'yCMqcFAigRg',
#   '8w4A1vVaNmE',
#   'V3QOzyS5M4Q',
#   'G2rSQF5Qx7k',
#   'MHDjff07l0I',
#   'M134RqAbiwY',
#   'qvcSth8LvEw',
#   '-zymq4JgQ7E',
#   '45KfDAgw_Is',
#   'RLmmqQNEM_I',
#   'rJVYkPjQf9s',
#   'DjABPXfE4Fs',
#   '0jWoq3COzts',
#   'bkADPxWSeak',
#   'm_4CSbzwPtE',
#   'Ivz6lNNAYaE',
#   'R7wjyOQw7Zw',
#   '1G1ES1y6AyI',
#   'Mi-FBBqUuJE',
#   'p-5R0u3iTiE',
#   'C7I3_yFQYkc',
#   'pA1dPsnfams',
#   'v9bxXO9fj98'],
#  'published_date': ['2024-07-09',
#   '2024-07-09',
#   '2024-06-21',
#   '2024-05-22',
#   '2024-05-03',
#   '2024-04-25',
#   '2024-04-22',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-20',
#   '2024-04-19',
#   '2024-04-19',
#   '2024-04-19',
#   '2024-04-19',
#   '2024-04-17',
#   '2024-02-13',
#   '2023-11-29',
#   '2023-11-27',
#   '2023-10-31',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-27',
#   '2023-10-19',
#   '2023-10-19',
#   '2023-09-26',
#   '2023-09-20',
#   '2023-08-31',
#   '2023-08-10',
#   '2023-07-21',
#   '2023-07-08',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-06-24',
#   '2023-05-27',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-06',
#   '2023-03-31',
#   '2023-03-03',
#   '2023-03-03',
#   '2023-03-03',
#   '2023-03-03',
#   '2023-02-10',
#   '2023-01-27',
#   '2023-01-26',
#   '2022-12-08',
#   '2022-11-18',
#   '2022-11-11',
#   '2022-11-11',
#   '2022-11-11',
#   '2022-11-11',
#   '2022-11-09',
#   '2022-11-08',
#   '2022-11-04',
#   '2022-11-04',
#   '2022-11-01',
#   '2022-10-26',
#   '2022-10-25',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-22',
#   '2022-10-21',
#   '2022-10-21',
#   '2022-10-21',
#   '2022-10-20',
#   '2022-10-18',
#   '2022-06-24',
#   '2022-06-24',
#   '2022-05-06',
#   '2022-01-21',
#   '2021-11-18',
#   '2021-11-18',
#   '2021-11-15',
#   '2021-11-15',
#   '2021-11-15',
#   '2021-11-14',
#   '2021-11-13',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-12',
#   '2021-11-05',
#   '2021-09-17',
#   '2021-07-24',
#   '2021-04-30',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-09',
#   '2021-04-07',
#   '2021-03-26',
#   '2021-03-26',
#   '2021-03-15',
#   '2021-02-12',
#   '2021-01-07',
#   '2021-01-07',
#   '2020-12-17',
#   '2020-12-17',
#   '2020-12-17',
#   '2020-12-17',
#   '2020-12-16',
#   '2020-12-15',
#   '2020-12-15',
#   '2020-12-15',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-12-11',
#   '2020-11-25',
#   '2020-11-24',
#   '2020-09-17',
#   '2020-08-18',
#   '2020-08-17',
#   '2020-07-30',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-07-24',
#   '2020-06-22',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-05-18',
#   '2020-03-20',
#   '2020-03-10',
#   '2020-03-06',
#   '2020-02-27',
#   '2020-02-18',
#   '2020-02-07',
#   '2020-01-31',
#   '2020-01-22',
#   '2019-12-23',
#   '2019-12-16',
#   '2019-12-06',
#   '2019-12-06',
#   '2019-11-27',
#   '2019-11-26',
#   '2019-11-22',
#   '2019-11-15',
#   '2019-11-13',
#   '2019-10-07',
#   '2019-10-07',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-23',
#   '2019-08-22',
#   '2019-08-22',
#   '2019-08-16',
#   '2019-08-15',
#   '2019-07-23',
#   '2019-07-18',
#   '2019-07-09',
#   '2019-06-20',
#   '2019-06-17',
#   '2019-06-14',
#   '2019-05-24',
#   '2019-05-22',
#   '2019-05-02',
#   '2019-05-01',
#   '2019-05-01',
#   '2019-04-30',
#   '2019-04-26',
#   '2018-12-13',
#   '2018-06-24',
#   '2018-05-15',
#   '2018-05-01',
#   '2018-04-05',
#   '2018-03-13',
#   '2018-03-13',
#   '2018-03-12',
#   '2018-02-09',
#   '2018-01-12',
#   '2017-12-14',
#   '2017-12-13',
#   '2017-12-06',
#   '2017-12-01',
#   '2017-11-15',
#   '2017-11-07',
#   '2017-11-03',
#   '2017-10-27',
#   '2017-10-23',
#   '2017-10-20',
#   '2017-10-17',
#   '2017-09-27',
#   '2017-09-26',
#   '2017-09-21',
#   '2017-09-21',
#   '2017-09-20',
#   '2017-09-03',
#   '2017-08-28',
#   '2017-08-25',
#   '2017-08-25',
#   '2017-02-02',
#   '2017-02-01',
#   '2017-02-01',
#   '2017-01-27',
#   '2017-01-27',
#   '2017-01-27',
#   '2016-04-13',
#   '2016-02-09',
#   '2016-01-07',
#   '2016-01-05',
#   '2016-01-01',
#   '2015-08-31',
#   '2015-05-18',
#   '2015-02-19',
#   '2015-02-19',
#   '2015-02-13',
#   '2014-12-31',
#   '2014-12-15',
#   '2014-11-10',
#   '2014-11-03',
#   '2014-10-20',
#   '2014-10-20',
#   '2014-10-16',
#   '2014-10-15',
#   '2014-10-13',
#   '2014-10-08',
#   '2014-10-06',
#   '2014-10-01',
#   '2014-09-24',
#   '2014-09-17',
#   '2014-09-12',
#   '2014-09-12',
#   '2014-09-12',
#   '2014-08-19',
#   '2014-08-18',
#   '2014-04-16',
#   '2014-02-13',
#   '2013-12-05',
#   '2013-11-16',
#   '2013-10-08',
#   '2013-09-30',
#   '2013-09-12',
#   '2013-09-06',
#   '2013-08-16',
#   '2013-08-14',
#   '2013-08-12',
#   '2013-08-01',
#   '2013-07-30',
#   '2013-07-29',
#   '2013-07-25',
#   '2013-07-03',
#   '2013-07-01',
#   '2013-06-13',
#   '2013-06-12',
#   '2013-06-06',
#   '2013-05-15',
#   '2013-05-08',
#   '2013-04-06',
#   '2013-03-15',
#   '2013-03-15',
#   '2013-03-15',
#   '2013-03-15',
#   '2013-03-13',
#   '2013-02-05',
#   '2013-02-05',
#   '2013-02-05',
#   '2013-01-27',
#   '2012-12-17',
#   '2012-12-14',
#   '2012-11-07',
#   '2012-11-06',
#   '2012-11-06',
#   '2012-11-06',
#   '2012-11-06',
#   '2012-11-06',
#   '2012-11-06',
#   '2012-11-02',
#   '2012-11-01',
#   '2012-10-31',
#   '2012-10-30',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-29',
#   '2012-10-27',
#   '2012-10-26',
#   '2012-10-26',
#   '2012-10-26',
#   '2012-10-25',
#   '2012-10-24',
#   '2012-10-24',
#   '2012-10-23',
#   '2012-09-20',
#   '2012-09-07',
#   '2012-09-01',
#   '2012-08-21',
#   '2012-08-14',
#   '2012-08-14',
#   '2012-08-07',
#   '2012-06-04',
#   '2012-05-17',
#   '2012-04-24',
#   '2012-04-02',
#   '2012-03-19',
#   '2012-02-29',
#   '2012-02-16',
#   '2012-02-16',
#   '2011-12-19',
#   '2011-12-16',
#   '2011-12-16',
#   '2011-12-16',
#   '2011-12-16',
#   '2011-12-13',
#   '2011-12-13',
#   '2011-12-09',
#   '2011-12-09',
#   '2011-12-09',
#   '2011-12-08',
#   '2011-12-07',
#   '2011-12-07',
#   '2011-12-06',
#   '2011-11-22',
#   '2011-11-19',
#   '2011-11-17',
#   '2011-11-17',
#   '2011-09-29',
#   '2011-09-21',
#   '2011-09-21',
#   '2011-09-16',
#   '2011-09-02',
#   '2011-08-25',
#   '2011-08-24',
#   '2011-08-24',
#   '2011-08-11',
#   '2011-05-25',
#   '2011-05-13',
#   '2011-04-04',
#   '2011-02-23',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-14',
#   '2011-02-01',
#   '2011-01-06',
#   '2010-12-08',
#   '2010-12-08',
#   '2010-12-08',
#   '2010-12-08',
#   '2010-12-08',
#   '2010-10-25',
#   '2010-10-19',
#   '2010-08-31',
#   '2010-06-02',
#   '2010-04-26',
#   '2010-04-26',
#   '2010-04-24',
#   '2010-04-02',
#   '2010-04-01',
#   '2010-03-25',
#   '2010-03-12',
#   '2010-03-01',
#   '2010-02-26',
#   '2009-11-24',
#   '2009-11-02',
#   '2009-10-01',
#   '2009-09-09',
#   '2009-08-19',
#   '2009-08-11',
#   '2009-06-17',
#   '2009-06-17',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-06-16',
#   '2009-05-08',
#   '2009-05-07',
#   '2009-04-24',
#   '2009-03-06',
#   '2009-03-05',
#   '2008-11-25',
#   '2008-11-17',
#   '2008-11-17',
#   '2008-11-17',
#   '2008-11-17',
#   '2008-11-17',
#   '2008-11-17',
#   '2008-09-02',
#   '2008-08-17',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26',
#   '2008-06-26'],
#  'title': ['Taylor Swift - Fortnight (feat. Post Malone) (Cults Remix)',
#   'Taylor Swift - Fortnight (feat. Post Malone) (Acoustic)',
#   'Taylor Swift - Fortnight (feat. Post Malone) (Behind the Scenes)',
#   'Taylor Swift - Fortnight\xa0(feat Post Malone)\xa0(BLOND:ISH Remix)',
#   'A fortnight since TTPD 🤍 brought to you by YouTube Shorts #ForAFortnightChallenge',
#   'A fortnight til Paris 🤍 Brought to you by YouTube Shorts #ForAFortnightChallenge',
#   'A fortnight making TTPD 🤍 Brought to you by YouTube Shorts #ForAFortnightChallenge',
#   'Taylor Swift - I Hate It Here (Official Lyric Video)',
#   'Taylor Swift - The Black Dog (Official Lyric Video)',
#   'Share your “fortnight” recap with #ForAFortnightChallenge 🤍 brought to you by YouTube Shorts',
#   'Taylor Swift - The Alchemy (Official Lyric Video)',
#   'Taylor Swift - Who’s Afraid of Little Old Me? (Official Lyric Video)',
#   'Taylor Swift - Florida!!! (feat. Florence + The Machine) (Official Lyric Video)',
#   'Taylor Swift - The Bolter (Official Lyric Video)',
#   'Taylor Swift - The Manuscript (Official Lyric Video)',
#   'Taylor Swift - The Prophecy (Official Lyric Video)',
#   'Taylor Swift - My Boy Only Breaks His Favorite Toys (Official Lyric Video)',
#   'Taylor Swift - The Tortured Poets Department (Official Lyric Video)',
#   'Taylor Swift -  So High School (Official Lyric Video)',
#   'Taylor Swift - thanK you aIMee (Official Lyric Video)',
#   'Taylor Swift - Chloe or Sam or Sophia or Marcus (Official Lyric Video)',
#   'Taylor Swift - Clara Bow (Official Lyric Video)',
#   'Taylor Swift - I Can Do It With a Broken Heart (Official Lyric Video)',
#   'Taylor Swift - I Can Fix Him (No Really I Can) (Official Lyric Video)',
#   'Taylor Swift - Guilty as Sin (Official Lyric Video)',
#   'Taylor Swift - Peter (Official Lyric Video)',
#   'Taylor Swift - Down Bad (Official Lyric Video)',
#   'Taylor Swift - Robin (Official Lyric Video)',
#   'Taylor Swift - imgonnagetyouback (Official Lyric Video)',
#   'Taylor Swift - loml (Official Lyric Video)',
#   'Taylor Swift - But Daddy I Love Him (Official Lyric Video)',
#   'Taylor Swift - How Did It End? (Official Lyric Video)',
#   'Taylor Swift - The Smallest Man Who Ever Lived (Official Lyric Video)',
#   'Taylor Swift - So Long, London (Official Lyric Video)',
#   'Taylor Swift - Fortnight (feat Post Malone) (Official Lyric Video)',
#   'Taylor Swift - Fortnight (feat. Post Malone) (Official Music Video)',
#   'Taylor Swift - The Albatross (Official Lyric Video)',
#   "Taylor Swift - I Look in People's Windows (Official Lyric Video)",
#   'Taylor Swift - Fresh Out The Slammer (Official Lyric Video)',
#   'Taylor Swift - Cassandra (Official Lyric Video)',
#   'Entering the Phantom Clear TTPD vinyl into evidence. Available exclusively at Target now',
#   'Taylor Swift - Fortnight (feat. Post Malone)',
#   'A message for the department 🤍#ForAFortnightChallenge coming soon to YouTube Shorts',
#   'Album tonight. Fortnight music video tomorrow at 8pm et.',
#   'The TTPD Timetable',
#   'accidentally going clubbing with your parents is something everyone should try at least once',
#   "Taylor Swift - You're Losing Me (From The Vault)",
#   'Rent on demand starting … you guessed it, December 13 🫶💋',
#   '✨🫶 My name is Taylor and I was born in 1989 🫶✨',
#   "Taylor Swift - Is It Over Now? (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Now That We Don't Talk (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Wildest Dreams (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Bad Blood (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - How You Get The Girl (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Out Of The Woods (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Blank Space (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Shake It Off (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - "Slut!" (Taylor\'s Version) (From The Vault) (Lyric Video)',
#   "Taylor Swift - All You Had To Do Was Stay (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Suburban Legends (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Welcome To New York (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Clean (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - You Are In Love (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Wonderland (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Say Don't Go (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - I Wish You Would (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Style (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - New Romantics (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - I Know Places (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Cruel Summer (Live from Taylor Swift | The Eras Tour)',
#   'Taylor Swift - Cruel Summer (LP Giobbi Remix)',
#   'The Eras Tour concert film is now officially coming to theaters WORLDWIDE on Oct 13! \U0001fa75',
#   'Thank you for making these reveals so much chaotic fun (which is the best kind of fun, after all 😜)',
#   'TAYLOR SWIFT | THE ERAS TOUR Concert Film Official Trailer',
#   'Pre order 1989 (Taylor’s Version) now on my site \U0001fa75😎\U0001fa75',
#   'Summer forecast: Cruel. 😎',
#   'Taylor Swift - I Can See You (Taylor’s Version) (From The Vault) (Official Video)',
#   "Taylor Swift - Innocent (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Never Grow Up (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Last Kiss (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Mine (Taylor's Version) (Lyric Video)",
#   'Electric Touch (Taylor’s Version) (From The Vault) (Lyric Video)',
#   "Taylor Swift - Back To December (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Timeless (Taylor’s Version) (From The Vault) (Lyric Video)',
#   "Taylor Swift - Sparks Fly (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Story Of Us (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Enchanted (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - I Can See You (Taylor’s Version) (From The Vault) (Lyric Video)',
#   'Castles Crumbling (Taylor’s Version) (From The Vault) (Lyric Video)',
#   'Taylor Swift - When Emma Falls in Love (Taylor’s Version) (Lyric Video)',
#   "Taylor Swift - Better Than Revenge (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Long Live (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Dear John (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Superman (Taylor’s Version) (Lyric Video)',
#   'Taylor Swift - Ours (Taylor’s Version) (Lyric Video)',
#   "Taylor Swift - Speak Now (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Mean (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Haunted (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Foolish One (Taylor’s Version) (From The Vault) (Lyric Video)',
#   '13 days til we return Speak Now to its mother 😝',
#   'Taylor Swift ft. Ice Spice - Karma (Official Music Video)',
#   'Taylor Swift - Hits Different',
#   'Taylor Swift ft. Ice Spice - Karma (Official Visualizer)',
#   'Taylor Swift - Snow On The Beach (Feat. More Lana Del Rey)',
#   'It fills me with such pride & joy to announce that my version of Speak Now will be out July 7 💜💜💜',
#   'Taylor Swift - Lavender Haze (Acoustic Version)',
#   'Taylor Swift - Lavender Haze (Snakehips Remix)',
#   'Taylor Swift - Lavender Haze (Jungle Remix)',
#   'Taylor Swift - Lavender Haze (Tensnake Remix)',
#   'Taylor Swift - Lavender Haze (Behind The Scenes)',
#   'Taylor Swift - Lavender Haze (Felix Jaehn Remix)',
#   'Taylor Swift - Lavender Haze (Official Music Video)',
#   'Meet me at midnight…for the Lavender Haze music video premiere (!!!!!!!!!!!!!)',
#   'Taylor Swift - All Too Well: The Short Film (Behind The Scenes)',
#   'Taylor Swift - Anti-Hero (ILLENIUM Remix)',
#   'It’s me, Benjamin 🐱 joining the #TSAntiHeroChallenge brought to you by YouTube Shorts',
#   'Taylor Swift - Anti-Hero (Roosevelt Remix)',
#   'Taylor Swift - Anti-Hero (Kungs Remix)',
#   'Taylor Swift - Anti-Hero (Jayda G Remix)',
#   'The Anti Hero (Roosevelt remix) makes me feel hyped enough for an imaginary funeral brawl',
#   'Taylor Swift - Anti-Hero (feat. Bleachers)',
#   'It’s me, 👋 sharing ALL the problems. Join the #TSAntiHeroChallenge brought to you by YouTube Shorts',
#   'Hits Different really hits different, plus it’s got one of my fav bridges 😆 only avail at Target',
#   'Total surprise 😉 Share yours with  #TSAntiHeroChallenge brought to you by YouTube Shorts.',
#   'We’re the problem',
#   'Taylor Swift - Bejeweled (Official Music Video)',
#   'Taylor Swift - Snow On The Beach (Lyric Video) ft. Lana Del Rey',
#   'Taylor Swift - Paris (Official Lyric Video)',
#   'Taylor Swift - Labyrinth (Lyric Video)',
#   'Taylor Swift - Question...? (Official Lyric Video)',
#   'Taylor Swift - Maroon (Official Lyric Video)',
#   'Taylor Swift - Lavender Haze (Official Lyric Video)',
#   'Taylor Swift - Sweet Nothing (Official Lyric Video)',
#   'Taylor Swift - The Great War (Official Lyric Video)',
#   'Taylor Swift - Karma (Lyric Video)',
#   'Taylor Swift - Bigger Than The Whole Sky (Lyric Video)',
#   'Taylor Swift - Dear Reader (Official Lyric Video)',
#   'Taylor Swift - Bejeweled (Lyric Video)',
#   'Taylor Swift - Glitch (Official Lyric Video)',
#   'Taylor Swift - Vigilante Shit (Official Lyric Video)',
#   'Taylor Swift - Mastermind (Official Lyric Video)',
#   'Taylor Swift - Anti-Hero (Official Lyric Video)',
#   "Taylor Swift - Would've, Could've, Should've (Official Lyric Video)",
#   'Taylor Swift - Midnight Rain (Official Lyric Video)',
#   "Taylor Swift - You're On Your Own, Kid (Official Lyric Video)",
#   'Taylor Swift - High Infidelity (Official Lyric Video)',
#   '🫣 Join my #TSAntiHeroChallenge and share your anti-heroic traits, brought to you by YouTube Shorts.',
#   '😺 Join my #TSAntiHeroChallenge and share your anti-heroic traits, brought to you by YouTube Shorts.',
#   'Taylor Swift - Anti-Hero (Official Music Video)',
#   'Mark your calendars! Meet the Midnights Manifest 📜',
#   '🕰 #TSAntiHeroChallenge. Coming October 21. Brought to you by YouTube Shorts.',
#   'Taylor Swift - Carolina (From The Motion Picture “Where The Crawdads Sing” / Lyric Video)',
#   'Taylor Swift - Carolina (From The Motion Picture “Where The Crawdads Sing” / Audio)',
#   "Taylor Swift - This Love (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Message In A Bottle (Fat Max G Remix) (Taylor’s Version) (Visualizer)',
#   'All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios (Lyric Video)',
#   'Taylor Swift - All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios',
#   "All Too Well (10 Minute Version) (Taylor's Version) (From The Vault) (Karaoke)",
#   "Taylor Swift - All Too Well (Taylor's Version) (Karaoke)",
#   "Taylor Swift ft. Chris Stapleton - I Bet You Think About Me (Taylor's Version) (Officia...",
#   'Taylor Swift - All Too Well (10 Minute Version) (Live on Saturday Night Live)',
#   'Taylor Swift - All Too Well: The Short Film',
#   "All Too Well (10 Minute Version) (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Starlight (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Red (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Run (Taylor's Version) (From The Vault) (Lyric Video) ft. Ed Sheeran",
#   "Taylor Swift - Treacherous (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - We Are Never Ever Getting Back Together (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - I Almost Do (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - I Knew You Were Trouble (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Stay Stay Stay (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Very First Night (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Nothing New (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Ronan (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Last Time (Taylor's Version) (Lyric Video) ft. Gary Lightbody",
#   "Taylor Swift - Message In A Bottle (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Come Back...Be Here (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Sad Beautiful Tragic (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Begin Again (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Everything Has Changed (Taylor's Version) (Lyric Video) ft. Ed Sheeran",
#   "Taylor Swift - Forever Winter (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Girl At Home (Taylor's Version) (Lyric Video)",
#   "I Bet You Think About Me (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - Holy Ground (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Moment I Knew (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Better Man (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - 22 (Taylor's Version) (Lyric Video)",
#   "I Bet You Think About Me (Taylor's Version) (From The Vault) (Lyric Video)",
#   "All Too Well (10 Minute Version) (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - State Of Grace (Acoustic Version) (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Babe (Taylor's Version) (From The Vault) (Lyric Video)",
#   "Taylor Swift - The Lucky One (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - All Too Well (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - State Of Grace (Taylor's Version) (Lyric Video)",
#   'All Too Well (The Short Film) | Official Trailer',
#   'Taylor Swift - Wildest Dreams (Taylor’s Version) (Official Audio)',
#   'taylor swift - the lakes (original version) [audio]',
#   "Taylor Swift - The Best Day (Taylor's Version) (Official Music Video)",
#   'Taylor Swift - Bye Bye Baby (Taylor’s Version) (From The Vault) (Lyric Video)',
#   'Taylor Swift - We Were Happy (Taylor’s Version) (From The Vault)',
#   "Taylor Swift - Breathe (Taylor's Version) (Lyric Video) ft. Colbie Caillat",
#   "Taylor Swift - Today Was A Fairytale (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Change (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Jump Then Fall (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Tell Me Why (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Hey Stephen (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Forever & Always (Piano Version) (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Fifteen (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - You Belong With Me (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - Don’t You (Taylor’s Version) (From The Vault) (Lyric Video)',
#   "Taylor Swift - Come In With The Rain (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Forever & Always (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Superstar (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Best Day (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Fearless (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - The Way I Loved You (Taylor's Version) (Lyric Video)",
#   'Taylor Swift - The Other Side Of The Door (Taylor’s Version) (Lyric Video)',
#   "Taylor Swift - You're Not Sorry (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - Untouchable (Taylor's Version) (Lyric Video)",
#   "Taylor Swift - White Horse (Taylor's Version) (Lyric Video)",
#   'That’s When (Taylor’s Version) (From The Vault) (Lyric Video)',
#   'Taylor Swift - Mr. Perfectly Fine (Taylor’s Version) (From The Vault) (Lyric Video)',
#   'Taylor Swift ft. Maren Morris - You All Over Me (From The Vault) (Official Lyric Video)',
#   'Taylor Swift - Love Story (Elvira Remix) (Taylor’s Version) (Official Audio)',
#   'Taylor Swift - cardigan / august / willow (Live From The 63rd GRAMMYs ® / 2021)',
#   'Taylor Swift - Love Story (Taylor’s Version) [Official Lyric Video]',
#   'Taylor Swift - right where you left me (Official Lyric Video)',
#   'Taylor Swift - it’s time to go (Official Lyric Video)',
#   'Taylor Swift - willow (moonlit witch version) - [yule log]',
#   'Taylor Swift - willow (lonely witch version) - [yule log]',
#   'Taylor Swift - willow (dancing witch version) - [yule log]',
#   'Taylor Swift - willow - [yule log]',
#   'Taylor Swift - willow (moonlit witch version)',
#   'Taylor Swift - willow (dancing witch version) - storyboards from the willow music video',
#   'Taylor Swift - willow (lonely witch version) - music video behind the scenes',
#   'Taylor Swift - willow - dancing witch version (Elvira remix)',
#   'Taylor Swift - dorothea (Official Lyric Video)',
#   'Taylor Swift - champagne problems (Official Lyric Video)',
#   'Taylor Swift - tolerate it (Official Lyric Video)',
#   'Taylor Swift - cowboy like me (Official Lyric Video)',
#   'Taylor Swift - happiness (Official Lyric Video)',
#   'Taylor Swift - long story short (Official Lyric Video)',
#   'Taylor Swift - no body, no crime (Official Lyric Video) ft. HAIM',
#   'Taylor Swift - willow (Official Music Video)',
#   'Taylor Swift - marjorie (Official Lyric Video)',
#   'Taylor Swift - coney island (Lyric Video) ft. The National',
#   'Taylor Swift - ivy (Official Lyric Video)',
#   'Taylor Swift - ‘tis the damn season (Official Lyric Video)',
#   'Taylor Swift - gold rush (Official Lyric Video)',
#   'Taylor Swift - evermore (Official Lyric Video) ft. Bon Iver',
#   'Taylor Swift - willow (Official Lyric Video)',
#   'Taylor Swift - closure (Official Lyric Video)',
#   'Taylor Swift - exile (folklore: the long pond studio sessions | Disney+) ft. Bon Iver',
#   'Taylor Swift – folklore: the long pond studio sessions | Official Trailer | Disney+',
#   'Taylor Swift - betty (Live from the 2020 Academy of Country Music Awards)',
#   'Taylor Swift - the lakes (Official Lyric Video)',
#   "Taylor Swift - The Making of 'cardigan' | Vevo Footnotes",
#   'Taylor Swift - cardigan (cabin in candlelight version / Visualizer)',
#   'Taylor Swift – exile (feat. Bon Iver) (Official Lyric Video)',
#   'Taylor Swift – hoax (Official Lyric Video)',
#   'Taylor Swift – seven (Official Lyric Video)',
#   'Taylor Swift – august (Official Lyric Video)',
#   'Taylor Swift - cardigan (Official Lyric Video)',
#   'Taylor Swift – peace (Official Lyric Video)',
#   'Taylor Swift - cardigan',
#   'Taylor Swift – my tears ricochet (Official Lyric Video)',
#   'Taylor Swift – this is me trying (Official Lyric Video)',
#   'Taylor Swift – mirrorball (Official Lyric Video)',
#   'Taylor Swift – illicit affairs (Official Lyric Video)',
#   'Taylor Swift – invisible string (Official Lyric Video)',
#   'Taylor Swift – betty (Official Lyric Video)',
#   'Taylor Swift - the 1 (Official Lyric Video)',
#   'Taylor Swift – mad woman (Official Lyric Video)',
#   'Taylor Swift – epiphany (Official Lyric Video)',
#   'Taylor Swift - the last great american dynasty (Official Lyric Video)',
#   'Taylor Swift - Cornelia Street (Live From Paris)',
#   'Taylor Swift - Death By A Thousand Cuts (Live From Paris)',
#   'Taylor Swift - Daylight (Live From Paris)',
#   'Taylor Swift - The Archer (Live From Paris)',
#   'Taylor Swift - ME! (Live From Paris)',
#   'Taylor Swift - You Need To Calm Down (Live From Paris)',
#   'Taylor Swift - Cornelia Street (Live From Paris)',
#   'Taylor Swift - Lover (Live From Paris)',
#   'Taylor Swift - The Man (Behind The Scenes: The Umpire)',
#   'Taylor Swift - The Man (Behind The Scenes: Directing)',
#   'Taylor Swift - The Man (Becoming The Man: Behind The Scenes)',
#   'Taylor Swift - The Man (Official Video)',
#   'Taylor Swift - The Man (Live From Paris)',
#   'Taylor Swift - The Man (Lyric Video)',
#   'Taylor Swift - Only The Young (Featured in Miss Americana / Lyric Video)',
#   'Miss Americana | Official Trailer',
#   'Taylor Swift - The Making Of Christmas Tree Farm',
#   'How To Be A Cat',
#   'Taylor Swift - Christmas Tree Farm',
#   'Taylor Swift - Christmas Tree Farm (Lyric Video)',
#   'Taylor Swift - Live at the 2019 American Music Awards',
#   'Taylor Swift - Lover (First Dance Remix)',
#   'Taylor Swift - Lover Remix Feat. Shawn Mendes (Snow Globe Lyric Video)',
#   'Taylor Swift - Beautiful Ghosts (From The Motion Picture "Cats" / Lyric Video)',
#   'Taylor Swift - Lover Remix Feat. Shawn Mendes (Lyric Video)',
#   'Taylor Swift - "False God" (Live on Saturday Night Live / 2019)',
#   'Taylor Swift - "Lover" (Live on Saturday Night Live / 2019)',
#   'Lover Album Photoshoot: Behind The Scenes',
#   'Taylor Swift - The Man (Official Audio)',
#   'Taylor Swift - Daylight (Official Audio)',
#   'Taylor Swift - It’s Nice To Have A Friend (Official Audio)',
#   'Taylor Swift - Cruel Summer (Official Audio)',
#   'Taylor Swift - I Forgot That You Existed (Official Audio)',
#   'Taylor Swift - Miss Americana & The Heartbreak Prince (Official Audio)',
#   'Taylor Swift - Soon You’ll Get Better (Official Audio) ft. The Chicks',
#   'Taylor Swift - Death By A Thousand Cuts (Official Audio)',
#   'Taylor Swift - Cornelia Street (Official Audio)',
#   'Taylor Swift - London Boy (Official Audio)',
#   'Taylor Swift - Paper Rings (Official Audio)',
#   'Taylor Swift - I Think He Knows (Official Audio)',
#   'Taylor Swift - False God (Official Audio)',
#   'Taylor Swift - Afterglow (Official Audio)',
#   'Taylor’s Diary -  Discusses Getting Her First Cat Meredith Grey, Tour and Middle School',
#   'Taylor Swift Answers Questions From Fans From Lover’s Lounge Live',
#   'Taylor’s Diary - My 13 Year Old Self (Exclusive Reading from Deluxe Edition Lover Album)',
#   'Taylor Swift - The Archer First Ever Live Performance',
#   "Taylor Swift - Lover's Lounge (Live)",
#   'Taylor Swift - Lover (Official Music Video)',
#   'Taylor Swift - Lover (Official Lyric Video)',
#   'Taylor Swift - Livestream Announcement (8/22/19 @ 5pm EST)',
#   'Taylor Swift - The Archer (Lyric Video)',
#   'You Need To Calm Down Behind The Scenes: Friends & Neighbors',
#   'You Need To Calm Down Behind The Scenes: Morning Routine',
#   'You Need To Calm Down Behind The Scenes: Pop Queen Pageant',
#   'Taylor Swift - You Need To Calm Down',
#   'Taylor Swift - You Need To Calm Down (Lyric Video)',
#   'Taylor Swift - ME! (Live on The Graham Norton Show)',
#   'Taylor Swift - ME! (Live on The Voice / 2019) ft. Brendon Urie',
#   'ME! (feat. Brendon Urie of Panic! At The Disco) (Live From The Billboard Music Awards /...',
#   'ME! (feat. Brendon Urie of Panic! At The Disco) (Lyric Video)',
#   'ME! Behind The Scenes: Je Suis Calme',
#   'ME! Behind The Scenes: The Story of Benjamin Button',
#   'Taylor Swift - ME! (feat. Brendon Urie of Panic! At The Disco) ft. Brendon Urie',
#   'Taylor Swift reputation Stadium Tour | Official Trailer | Netflix',
#   'Taylor Swift and Robbie Williams - Angels - reputation Stadium Tour',
#   'Taylor Swift - Delicate (Vertical Version)',
#   'Taylor Swift reputation Stadium Tour - Official Merch',
#   'Taylor Swift reputation Stadium Tour // Trailer 2',
#   'Delicate Music Video Dance Rehearsal Part 2',
#   'Delicate Music Video Dance Rehearsal Part 1',
#   'Taylor Swift - Delicate',
#   'End Game - Behind The Scenes',
#   'Taylor Swift - End Game ft. Ed Sheeran, Future',
#   'Taylor Swift, BloodPop® - ...Ready For It?',
#   "Taylor Swift's reputation Stadium Tour - Trailer",
#   'Taylor Swift - …Ready for It? (BloodPop® Remix) (Audio)',
#   'TaylorSwiftVEVO Live Stream',
#   'The Making of a Song: “Delicate” – watch more on Taylor Swift NOW',
#   'The reputation Secret Sessions',
#   'Taylor Swift - Call It What You Want (Lyric Video)',
#   'Taylor Swift - …Ready For It?',
#   '...Ready For It? Trailer',
#   'Taylor Swift - Gorgeous (Lyric Video)',
#   'Look What You Made Me Do - Looks',
#   'Look What You Made Me Do - Stream Co.',
#   'Taylor Swift Live Stream',
#   'Look What You Made Me Do - The Birdcage',
#   'Look What You Made Me Do - Zombie Transformation',
#   'Look What You Made Me Do: Taylor Mountain',
#   'Taylor Swift - ...Ready For It? (Audio)',
#   'Taylor Swift - Look What You Made Me Do',
#   'Official "Look What You Made Me Do" Video Teaser Clip',
#   'Taylor Swift - Look What You Made Me Do (Lyric Video)',
#   'Rehearsing "I Don\'t Wanna Live Forever (Fifty Shades Darker)" for DIRECTV NOW Super Saturday Night',
#   'First time hearing "I Don\'t Wanna Live Forever (Fifty Shades Darker)" on the radio',
#   'I Don’t Wanna Live Forever (Fifty Shades Darker) BTS 4 – Glitter Lip [EXTENDED]',
#   "I Don't Wanna Live Forever (Fifty Shades Darker) BTS 1 - Zayn & Taylor [EXTENDED]",
#   "I Don't Wanna Live Forever (Fifty Shades Darker) BTS 2 - Key Light? [EXTENDED]",
#   'ZAYN, Taylor Swift - I Don’t Wanna Live Forever (Fifty Shades Darker)',
#   'Taylor Swift - New Romantics',
#   'Taylor Swift - Out Of The Woods – The Making Of',
#   'Taylor performs "Blank Space" at The GRAMMY Museum',
#   'Taylor Performs "Wildest Dreams" at The GRAMMY Museum',
#   'Taylor Swift - Out Of The Woods',
#   'Taylor Swift - Wildest Dreams',
#   'Taylor Swift - Bad Blood ft. Kendrick Lamar',
#   '#STYLEmemories One',
#   '#STYLEmemories Two',
#   'Taylor Swift - Style',
#   "Taylor Swift's Gift Giving of 2014 | SWIFTMAS",
#   'Behind The Fragrance, Taylor Swift Incredible Things featuring Taylor Swift (Behind The Scenes)',
#   'Taylor Swift - Blank Space',
#   "Taylor Swift's The 1989 World Tour",
#   'Preview "Welcome To New York" by Taylor Swift',
#   'Taylor Swift talks about "Welcome to New York"',
#   '1989 Secret Sessions, Behind The Scenes!',
#   'Taylor Swift - Shake It Off Outtakes Video #8 - The Director',
#   'Taylor Swift Talks About "Out Of The Woods"',
#   'Taylor Swift - Shake It Off Outtakes Video #7 - The Band, The Fans and The Extras',
#   'Taylor Swift Ice Bucket Challenge with Jamie King',
#   'Shake It Off Outtakes Video #6 - The Ribbon Dancers (Behind The Scenes Video)',
#   'Shake It Off Outtakes Video #5 - The Twerkers and Finger Tutting (Behind-The-Scenes Video)',
#   'Taylor Swift - Shake It Off Outtakes Video #4 - The Animators (Behind The Scenes Video)',
#   'Taylor Swift - Shake It Off Outtakes Video #1 - The Cheerleaders (Behind The Scenes Video)',
#   'Taylor Swift - Shake It Off Outtakes Video #2 - The Ballerinas (Behind The Scenes Video)',
#   'Shake It Off Outtakes Video #3 - The Modern Dancers (Behind The Scenes Video)',
#   "Taylor Swift's Worldwide Live Stream on Yahoo - Highlights",
#   'Taylor Swift - Shake It Off',
#   'Surprising Gena',
#   'Taylor Swift RED Tour Asia announcement',
#   'Taylor Swift Fragrances Made Of Starlight Musical Edition',
#   'Taylor Swift - The Last Time ft. Gary Lightbody',
#   'Taylor Swift RED Tour Nashville Week',
#   'Taylor Swift RED Tour London announcement',
#   'Taylor Swift and Jennifer Lopez: Jenny from the Block',
#   "Behind the scenes of Taylor Swift's week at Staples Center",
#   'Taylor Swift on Style: Outtakes',
#   'Taylor Swift on Style: Part 4',
#   'Taylor Swift on Style: Part 3',
#   'Q&A with Taylor on Taylor By Taylor Swift, the fragrance',
#   '#HiFromTaylor Teaser',
#   "Taylor Swift and Carly Simon: You're So Vain",
#   'Welcome to the Official Taylor Swift YouTube Channel!',
#   'Taylor Swift - Red',
#   'Taylor by Taylor Swift Fragrance Video Part 1',
#   'Taylor By Taylor Swift commercial: sneak peek',
#   "Britain's Got Talent performance: Everything Has Changed",
#   'Taylor Swift - Everything Has Changed ft. Ed Sheeran',
#   'Taylor Swift - Billboard Milestone Award',
#   'The RED Tour Australia/New Zealand Announcement!',
#   'Vote Taylor Swift ACM Entertainer of the Year: VoteACM.com',
#   '"Red" Guitar Solo from RED Tour Opening Night',
#   '"Holy Ground" Live on the RED Tour!',
#   '"Sparks Fly" (acoustic) Live on the RED Tour!',
#   'What Fans Can Expect on the RED Tour',
#   'Taylor Swift - 22',
#   '"I Knew You Were Trouble." Behind-The-Scenes #1',
#   '"I Knew You Were Trouble." Behind-The-Scenes #3',
#   '"I Knew You Were Trouble." Behind-The-Scenes #2',
#   'Some extraordinary news...',
#   'Taylor Swift - Acoustic Performances from RED Album',
#   'Taylor Swift - I Knew You Were Trouble',
#   'VH1 StoryTellers - Taylor Swift - Nov 11 @ 11/10c',
#   'Taylor Swift - We Are Never Ever Getting Back Together (Live from New York City)',
#   'Taylor Swift - Red (Live from New York City)',
#   'Taylor Swift - You Belong With Me (Live from New York City)',
#   'Taylor Swift - Mean (Live from New York City)',
#   'Taylor Swift - Begin Again (Live from New York City)',
#   'Taylor Swift - Love Story (Live from New York City)',
#   '"Starlight" Song Preview from RED - Now Available',
#   '"Everything Has Changed" Song Preview from RED - Now Available',
#   '"The Lucky One" Song Preview from RED - Now Available',
#   '"Sad Beautiful Tragic" Song Preview from RED - Now Available',
#   '"Holy Ground" Song Preview from RED - Now Available',
#   'Taylor Swift - #VevoCertified, Pt. 5: You Belong With Me (Taylor Commentary)',
#   'Taylor Swift - #VevoCertified, Pt. 4: Taylor Superfans aka Swifties',
#   'Taylor Swift - #VevoCertified, Pt. 6: Mine (Taylor Commentary)',
#   'Taylor Swift - #VEVOCertified, Pt. 7: Love Story (Taylor Commentary)',
#   'Taylor Swift - #VEVOCertified, Pt. 2: Taylor On Making Music Videos',
#   'Taylor Swift - #VEVOCertified, Pt. 3: Taylor Talks About Her Fans',
#   'Taylor Swift - #VevoCertified, Pt. 1: Award Presentation',
#   "Taylor Swift's RED Tour Announcement!",
#   '"Stay Stay Stay" Song Preview from RED - Now Available',
#   '"The Last Time" Song Preview from RED - Now Available',
#   '"I Almost Do" Song Preview from RED - Now Available',
#   '"22" Song Preview from RED - Now Available',
# ...
#   '62',
#   '194430',
#   '148574',
#   '1201883',
#   '3904972',
#   '97019',
#   '1561662',
#   '89431',
#   '23593',
#   '92',
#   '24872',
#   '137143',
#   '206360',
#   '600439',
#   '13467043',
#   '112954',
#   '2189469',
#   '34017',
#   '159910',
#   '71001',
#   '187074',
#   '30883',
#   '5230226',
#   '1148286',
#   '214714',
#   '466476',
#   '416158',
#   '1997304',
#   '5546279',
#   '10116539',
#   '9974',
#   '9946',
#   '4231585',
#   '185936',
#   '19004',
#   '15751184',
#   '10809',
#   '18984',
#   '11609',
#   '90182',
#   '91532',
#   '23743',
#   '56661',
#   '13192',
#   '45868',
#   '60396',
#   '55793',
#   '164733',
#   '89839',
#   '56351',
#   '8360',
#   '13482408',
#   '58394',
#   '7376',
#   '12673',
#   '369126',
#   '16391',
#   '4610',
#   '113527',
#   '14590',
#   '4439',
#   '2867',
#   '3453',
#   '5858',
#   '4292',
#   '22276',
#   '3780',
#   '1483545',
#   '10329',
#   '12404',
#   '74134',
#   '3274003',
#   '3696',
#   '5392',
#   '4042',
#   '10834',
#   '8694',
#   '18587',
#   '4888',
#   '3435972',
#   '19738',
#   '10568',
#   '10310',
#   '19541',
#   '204497',
#   '3783771',
#   '3940',
#   '108305',
#   '138079',
#   '91959',
#   '66291',
#   '58287',
#   '244205',
#   '2821',
#   '2314',
#   '2170',
#   '1977',
#   '2115',
#   '18481',
#   '6667',
#   '11540',
#   '14052',
#   '9946',
#   '12360',
#   '16517',
#   '10246',
#   '2219',
#   '1823',
#   '2099',
#   '3104',
#   '3574',
#   '1286484',
#   '3647',
#   '14610',
#   '276754',
#   '4307964',
#   '4878',
#   '275144',
#   '27127',
#   '10489',
#   '37143',
#   '173422',
#   '19614',
#   '41602',
#   '57215',
#   '22313',
#   '1975039',
#   '21523',
#   '6196',
#   '3178',
#   '4622',
#   '6467',
#   '2753',
#   '2671',
#   '3183',
#   '3170',
#   '2384',
#   '3391',
#   '2559',
#   '3060',
#   '3328',
#   '805405',
#   '5641',
#   '3463',
#   '5270',
#   '5502',
#   '25251',
#   '21969',
#   '5342',
#   '9028',
#   '29589',
#   '5303',
#   '160216',
#   '25140',
#   '542272',
#   '800630',
#   '1382486',
#   '207591',
#   '99258',
#   '2306',
#   '1967',
#   '1642',
#   '1711',
#   '1541',
#   '3486',
#   '2109',
#   '2341',
#   '1484',
#   '1692',
#   '1827578',
#   '12680',
#   '62263',
#   '136421',
#   '49080',
#   '290661',
#   '142188',
#   '73274',
#   '4947',
#   '1319325',
#   '13095',
#   '165564',
#   '20989',
#   '8041',
#   '7105',
#   '10590',
#   '12580',
#   '57080',
#   '15338',
#   '288942',
#   '670699',
#   '7310',
#   '7492',
#   '31002',
#   '26170',
#   '6673',
#   '938437',
#   '354392',
#   '841320',
#   '731151',
#   '10257988',
#   '5418056',
#   '235361',
#   '193270',
#   '181915',
#   '661842',
#   '20684',
#   '177280',
#   '7987',
#   '7864',
#   '34804',
#   '8067',
#   '72924',
#   '6905',
#   '21836',
#   '6807',
#   '7953',
#   '10651',
#   '3453',
#   '10280',
#   '4960',
#   '11175',
#   '10300',
#   '4150',
#   '9069',
#   '21241',
#   '24039',
#   '117869'],
#  'views': ['731187',
#   '1413253',
#   '2551044',
#   '1927751',
#   '30703768',
#   '34552966',
#   '35417173',
#   '4896550',
#   '5856060',
#   '121241310',
#   '7170412',
#   '16719755',
#   '9098224',
#   '3117060',
#   '1762018',
#   '6887779',
#   '12530732',
#   '11443787',
#   '8867299',
#   '4533474',
#   '3061011',
#   '4195039',
#   '23153044',
#   '4156116',
#   '15867453',
#   '4580928',
#   '18190680',
#   '1399060',
#   '6070889',
#   '9685663',
#   '13304168',
#   '4694920',
#   '8759064',
#   '13296909',
#   '2691454',
#   '96675146',
#   '2985854',
#   '2311716',
#   '6135351',
#   '2203800',
#   '1466168',
#   '13235417',
#   '1340475',
#   '2511191',
#   '1333475',
#   '3164318',
#   '21871440',
#   '3944859',
#   '2785560',
#   '24610395',
#   '15881067',
#   '11171044',
#   '8151028',
#   '5109845',
#   '8524703',
#   '17053486',
#   '11287815',
#   '11375093',
#   '5505842',
#   '4750585',
#   '14265569',
#   '8854635',
#   '5613655',
#   '4871236',
#   '12287684',
#   '4034666',
#   '21446446',
#   '7173070',
#   '5079083',
#   '4499774',
#   '909525',
#   '2311971',
#   '1757901',
#   '14476491',
#   '2345111',
#   '4788452',
#   '41866418',
#   '3776349',
#   '3626937',
#   '7665429',
#   '16105096',
#   '4373165',
#   '30843158',
#   '7463744',
#   '12996635',
#   '9704930',
#   '49122770',
#   '4808404',
#   '4694554',
#   '3998349',
#   '8852298',
#   '21647788',
#   '10083746',
#   '2022640',
#   '2463408',
#   '12733726',
#   '4863112',
#   '6289171',
#   '6850339',
#   '7625582',
#   '64528124',
#   '10420980',
#   '5149583',
#   '13586877',
#   '1198429',
#   '1847863',
#   '796227',
#   '272034',
#   '300476',
#   '1808769',
#   '742050',
#   '64898611',
#   '2091179',
#   '6965888',
#   '1856995',
#   '52247183',
#   '676318',
#   '1456522',
#   '721582',
#   '3226720',
#   '2247395',
#   '61845314',
#   '3510884',
#   '79205429',
#   '2987283',
#   '85353890',
#   '29865835',
#   '8865741',
#   '11626071',
#   '14017148',
#   '30801875',
#   '23825919',
#   '11080535',
#   '21372064',
#   '29115475',
#   '9302529',
#   '5653039',
#   '19320748',
#   '4628458',
#   '16254088',
#   '15876015',
#   '33181026',
#   '18494977',
#   '47906552',
#   '44829757',
#   '9114624',
#   '126714706',
#   '106053293',
#   '205628330',
#   '1643022',
#   '1674535',
#   '6944381',
#   '3798203',
#   '21680707',
#   '3877181',
#   '5341431',
#   '13491455',
#   '1604374',
#   '743653',
#   '64035694',
#   '25475127',
#   '100586461',
#   '120214451',
#   '4020143',
#   '46869303',
#   '8473440',
#   '5653766',
#   '20923443',
#   '7199406',
#   '18430082',
#   '5661147',
#   '9938910',
#   '9820638',
#   '3733244',
#   '9775742',
#   '13781362',
#   '9144008',
#   '4536711',
#   '5259241',
#   '8703256',
#   '4495800',
#   '3370605',
#   '1278500',
#   '4052364',
#   '5270232',
#   '16228954',
#   '12295681',
#   '8732517',
#   '31073682',
#   '2018057',
#   '11730395',
#   '4225514',
#   '17266829',
#   '9109993',
#   '1733970',
#   '34089851',
#   '3684196',
#   '5563041',
#   '3537084',
#   '2792739',
#   '9415257',
#   '3815355',
#   '3488199',
#   '4994666',
#   '3742119',
#   '8622609',
#   '2821388',
#   '8471600',
#   '37775180',
#   '3208694',
#   '2064695',
#   '6333803',
#   '2214289',
#   '7745088',
#   '38755710',
#   '82359318',
#   '3966533',
#   '9135217',
#   '6683676',
#   '10205101',
#   '4649230',
#   '44965080',
#   '9549391',
#   '2940572',
#   '10166834',
#   '49261873',
#   '27724384',
#   '11457016',
#   '982562',
#   '655772',
#   '495214',
#   '777317',
#   '1604534',
#   '1058929',
#   '2624215',
#   '1826769',
#   '11335755',
#   '60478627',
#   '20039905',
#   '11905730',
#   '10369004',
#   '12092166',
#   '25827529',
#   '145638358',
#   '14089944',
#   '12832424',
#   '15560095',
#   '15493464',
#   '17284968',
#   '20605607',
#   '15099224',
#   '5092850',
#   '23594812',
#   '1574829',
#   '23850684',
#   '13076209',
#   '2897257',
#   '4456529',
#   '108640655',
#   '13288668',
#   '21276983',
#   '100476474',
#   '33068889',
#   '10054757',
#   '180485076',
#   '41402759',
#   '22398462',
#   '27082564',
#   '26425829',
#   '28069142',
#   '29064354',
#   '57338415',
#   '13425245',
#   '12198964',
#   '27210018',
#   '13627602',
#   '4033969',
#   '2347845',
#   '849597',
#   '711698',
#   '579757',
#   '7067203',
#   '1019976',
#   '840668',
#   '2090824',
#   '4148916',
#   '102791915',
#   '8726421',
#   '30849879',
#   '13655533',
#   '8137594',
#   '1744469',
#   '1386699',
#   '19776153',
#   '3834303',
#   '110549385',
#   '4011457',
#   '2633933',
#   '7912491',
#   '51280198',
#   '5550742',
#   '4627772',
#   '2432240',
#   '23856092',
#   '63582287',
#   '7456860',
#   '199077657',
#   '27970074',
#   '35270293',
#   '9923828',
#   '16344117',
#   '50177445',
#   '34525132',
#   '47450032',
#   '18604510',
#   '13303723',
#   '29514649',
#   '116831',
#   '307164',
#   '255468',
#   '406404',
#   '16167402',
#   '299841905',
#   '52916980',
#   '13827661',
#   '38713931',
#   '2199833',
#   '3401800',
#   '3173093',
#   '349658889',
#   '34291627',
#   '5138983',
#   '13004268',
#   '74837321',
#   '10310075',
#   '5169901',
#   '6763281',
#   '432530388',
#   '5625012',
#   '2738734',
#   '7585093',
#   '514505',
#   '429958',
#   '2376437',
#   '8780023',
#   '556263360',
#   '2335735',
#   '296866236',
#   '9881529',
#   '557884',
#   '3724968',
#   '0',
#   '4892186',
#   '3277955',
#   '106712735',
#   '358066737',
#   '3748744',
#   '167422815',
#   '2054444',
#   '868924',
#   '0',
#   '806378',
#   '7293205',
#   '8146128',
#   '64567312',
#   '1494019907',
#   '4853276',
#   '149293290',
#   '1164226',
#   '2910860',
#   '3130045',
#   '6292203',
#   '945243',
#   '730946569',
#   '126250022',
#   '8460947',
#   '22680294',
#   '22835360',
#   '201918505',
#   '936888077',
#   '1623080128',
#   '253508',
#   '244794',
#   '856901875',
#   '20061538',
#   '504855',
#   '3470461703',
#   '722245',
#   '2132529',
#   '634874',
#   '3717303',
#   '10917691',
#   '1398780',
#   '6603831',
#   '403424',
#   '4767332',
#   '8015626',
#   '6243290',
#   '18048634',
#   '10367462',
#   '5239448',
#   '423086',
#   '3460688065',
#   '3526096',
#   '271559',
#   '492584',
#   '50093376',
#   '956822',
#   '207835',
#   '13069082',
#   '814586',
#   '185343',
#   '109851',
#   '125692',
#   '245810',
#   '152055',
#   '1307179',
#   '104549',
#   '244081647',
#   '650998',
#   '345759',
#   '2787583',
#   '411997591',
#   '108161',
#   '236013',
#   '127814',
#   '434876',
#   '352201',
#   '739999',
#   '170795',
#   '680825688',
#   '944210',
#   '416863',
#   '431304',
#   '1172663',
#   '10136343',
#   '525113045',
#   '199409',
#   '13266155',
#   '15800520',
#   '8504067',
#   '5825624',
#   '4298641',
#   '16025909',
#   '183697',
#   '187391',
#   '211250',
#   '201403',
#   '122832',
#   '1802273',
#   '649639',
#   '848251',
#   '1076494',
#   '779318',
#   '805916',
#   '3546270',
#   '522422',
#   '107931',
#   '78572',
#   '203600',
#   '197098',
#   '137381',
#   '206417626',
#   '184841',
#   '562029',
#   '37562067',
#   '785847858',
#   '339252',
#   '38396817',
#   '1966278',
#   '1011591',
#   '995058',
#   '18498205',
#   '935544',
#   '1190071',
#   '1935257',
#   '2449610',
#   '206711012',
#   '1485643',
#   '284034',
#   '168631',
#   '162212',
#   '268958',
#   '117916',
#   '101629',
#   '136373',
#   '198008',
#   '96574',
#   '184122',
#   '131290',
#   '163378',
#   '152384',
#   '112022967',
#   '249141',
#   '197530',
#   '300879',
#   '273151',
#   '1675525',
#   '1198591',
#   '272823',
#   '383562',
#   '2490281',
#   '323987',
#   '7088704',
#   '1837908',
#   '98658803',
#   '149579523',
#   '228064054',
#   '3477264',
#   '2485376',
#   '209590',
#   '91059',
#   '116407',
#   '52562',
#   '114940',
#   '407731',
#   '52557',
#   '118282',
#   '82878',
#   '54025',
#   '334643622',
#   '958817',
#   '6917122',
#   '17946399',
#   '5230846',
#   '24982356',
#   '13065187',
#   '1661627',
#   '394830',
#   '321124208',
#   '549457',
#   '5715051',
#   '1537193',
#   '1006750',
#   '338414',
#   '1051681',
#   '877541',
#   '1340012',
#   '907553',
#   '63308140',
#   '168605140',
#   '930309',
#   '651087',
#   '958104',
#   '1122073',
#   '442816',
#   '217665305',
#   '52885937',
#   '171746396',
#   '160454704',
#   '1613276632',
#   '749859907',
#   '25687809',
#   '51345037',
#   '41618845',
#   '122577869',
#   '5678358',
#   '3056035',
#   '1039812',
#   '648019',
#   '2886225',
#   '809542',
#   '3236093',
#   '706567',
#   '1506598',
#   '355872',
#   '508862',
#   '805683',
#   '310719',
#   '1022852',
#   '685376',
#   '668058',
#   '852647',
#   '356895',
#   '778402',
#   '1262394',
#   '917396',
#   '7667369'],
#  'comments': ['4776',
#   '5115',
#   '7567',
#   '7193',
#   '16225',
#   '21569',
#   '20795',
#   '4752',
#   '2430',
#   '49112',
#   '2182',
#   '5958',
#   '3034',
#   '1123',
#   '942',
#   '1990',
#   '2555',
#   '4581',
#   '3319',
#   '3681',
#   '1205',
#   '1263',
#   '6595',
#   '1027',
#   '2513',
#   '1995',
#   '3511',
#   '1007',
#   '2049',
#   '2565',
#   '3777',
#   '1446',
#   '2681',
#   '3316',
#   '936',
#   '96034',
#   '982',
#   '980',
#   '1952',
#   '1753',
#   '2810',
#   '29859',
#   '1877',
#   '5050',
#   '4022',
#   '7196',
#   '21116',
#   '14304',
#   '8192',
#   '7884',
#   '5407',
#   '3289',
#   '4687',
#   '1973',
#   '3658',
#   '7141',
#   '4761',
#   '5042',
#   '1590',
#   '2311',
#   '6507',
#   '3848',
#   '2828',
#   '2062',
#   '4383',
#   '1454',
#   '9461',
#   '5059',
#   '2998',
#   '12311',
#   '3826',
#   '6217',
#   '2882',
#   '20594',
#   '5437',
#   '6975',
#   '47020',
#   '2534',
#   '3061',
#   '3386',
#   '4433',
#   '2932',
#   '8280',
#   '4140',
#   '3146',
#   '2646',
#   '15022',
#   '3705',
#   '3314',
#   '3012',
#   '5802',
#   '6085',
#   '4390',
#   '1500',
#   '1524',
#   '7785',
#   '2597',
#   '4522',
#   '4676',
#   '11119',
#   '51862',
#   '6936',
#   '14177',
#   '14298',
#   '3631',
#   '3527',
#   '920',
#   '1041',
#   '779',
#   '3732',
#   '2360',
#   '44232',
#   '2537',
#   '7382',
#   '2520',
#   '15178',
#   '1526',
#   '1040',
#   '733',
#   '1796',
#   '4066',
#   '17365',
#   '3447',
#   '25187',
#   '2183',
#   '54539',
#   '8562',
#   '1943',
#   '2315',
#   '2501',
#   '4659',
#   '4862',
#   '2281',
#   '3724',
#   '6212',
#   '3681',
#   '1943',
#   '2129',
#   '1198',
#   '3960',
#   '2646',
#   '3236',
#   '5131',
#   '5926',
#   '5048',
#   '2742',
#   '23881',
#   '16580',
#   '99580',
#   '1256',
#   '1626',
#   '11290',
#   '5884',
#   '23377',
#   '7845',
#   '5634',
#   '17827',
#   '2964',
#   '3025',
#   '47902',
#   '22310',
#   '133844',
#   '50968',
#   '2628',
#   '13078',
#   '4255',
#   '2662',
#   '6361',
#   '2880',
#   '5637',
#   '3359',
#   '3415',
#   '4388',
#   '5928',
#   '3365',
#   '5884',
#   '2359',
#   '2195',
#   '2728',
#   '3622',
#   '2703',
#   '2729',
#   '1348',
#   '2121',
#   '2576',
#   '4849',
#   '8337',
#   '2754',
#   '9939',
#   '1402',
#   '4861',
#   '4532',
#   '6227',
#   '7345',
#   '13328',
#   '21672',
#   '13589',
#   '7999',
#   '4608',
#   '4164',
#   '5240',
#   '3741',
#   '3242',
#   '2819',
#   '2329',
#   '5469',
#   '2662',
#   '9219',
#   '15230',
#   '3567',
#   '2607',
#   '3293',
#   '2999',
#   '7642',
#   '12570',
#   '8545',
#   '2545',
#   '4932',
#   '4369',
#   '7845',
#   '4965',
#   '37660',
#   '22089',
#   '8635',
#   '27730',
#   '92034',
#   '15577',
#   '10352',
#   '1416',
#   '1032',
#   '1520',
#   '3302',
#   '3166',
#   '2668',
#   '4693',
#   '4295',
#   '8954',
#   '18489',
#   '8642',
#   '6755',
#   '6609',
#   '5074',
#   '14414',
#   '117196',
#   '11915',
#   '6569',
#   '7052',
#   '5932',
#   '8751',
#   '11674',
#   '4710',
#   '4585',
#   '18976',
#   '11291',
#   '29161',
#   '15944',
#   '4431',
#   '2970',
#   '44900',
#   '8864',
#   '11973',
#   '35833',
#   '5984',
#   '6554',
#   '146821',
#   '12424',
#   '9094',
#   '8595',
#   '7349',
#   '9346',
#   '17133',
#   '19064',
#   '8413',
#   '9626',
#   '11687',
#   '11161',
#   '2611',
#   '2222',
#   '1024',
#   '1406',
#   '1059',
#   '4764',
#   '1409',
#   '1157',
#   '3356',
#   '6649',
#   '113043',
#   '9442',
#   '19824',
#   '16155',
#   '14573',
#   '5104',
#   '3841',
#   '26813',
#   '4117',
#   '73690',
#   '6759',
#   '2465',
#   '14735',
#   '26397',
#   '4930',
#   '4544',
#   '1745',
#   '7367',
#   '12231',
#   '5913',
#   '32792',
#   '8190',
#   '9046',
#   '6480',
#   '4235',
#   '8768',
#   '11252',
#   '9371',
#   '5622',
#   '3951',
#   '6598',
#   '173',
#   '623',
#   '493',
#   '1234',
#   '4347',
#   '105149',
#   '42456',
#   '4778',
#   '38893',
#   '2365',
#   '4342',
#   '4522',
#   '249519',
#   '51003',
#   '6811',
#   '12119',
#   '54730',
#   '7481',
#   '6103',
#   '10838',
#   '439092',
#   '14892',
#   '3946',
#   '10096',
#   '2332',
#   '2098',
#   '1785',
#   '3979',
#   '209877',
#   '3723',
#   '177940',
#   '11460',
#   '2153',
#   '2149',
#   '1',
#   '5106',
#   '6302',
#   '52584',
#   '207906',
#   '7727',
#   '74838',
#   '1817',
#   '506',
#   '0',
#   '960',
#   '3901',
#   '4755',
#   '43985',
#   '756101',
#   '5838',
#   '198135',
#   '2024',
#   '4695',
#   '2410',
#   '4782',
#   '633',
#   '134335',
#   '60965',
#   '7699',
#   '13426',
#   '13561',
#   '130260',
#   '235712',
#   '469341',
#   '318',
#   '264',
#   '163296',
#   '16733',
#   '595',
#   '663500',
#   '1050',
#   '1473',
#   '332',
#   '5112',
#   '1991',
#   '1037',
#   '1379',
#   '337',
#   '1467',
#   '1843',
#   '1502',
#   '3905',
#   '2022',
#   '1086',
#   '313',
#   '586585',
#   '3684',
#   '1242',
#   '363',
#   '10652',
#   '1074',
#   '1209',
#   '3458',
#   '1018',
#   '258',
#   '131',
#   '203',
#   '421',
#   '400',
#   '1095',
#   '435',
#   '62705',
#   '1029',
#   '983',
#   '2907',
#   '156894',
#   '384',
#   '1756',
#   '491',
#   '821',
#   '678',
#   '934',
#   '521',
#   '287359',
#   '875',
#   '488',
#   '411',
#   '3136',
#   '10828',
#   '271421',
#   '271',
#   '5039',
#   '7232',
#   '3368',
#   '2529',
#   '2750',
#   '5672',
#   '253',
#   '221',
#   '217',
#   '145',
#   '200',
#   '1582',
#   '925',
#   '721',
#   '921',
#   '435',
#   '843',
#   '1642',
#   '3215',
#   '222',
#   '135',
#   '167',
#   '359',
#   '444',
#   '60618',
#   '470',
#   '1002',
#   '8682',
#   '226545',
#   '1287',
#   '35527',
#   '1300',
#   '4943',
#   '2047',
#   '11277',
#   '1286',
#   '3757',
#   '4282',
#   '962',
#   '106675',
#   '1095',
#   '560',
#   '173',
#   '139',
#   '288',
#   '107',
#   '309',
#   '271',
#   '352',
#   '129',
#   '243',
#   '115',
#   '205',
#   '264',
#   '40166',
#   '772',
#   '382',
#   '548',
#   '545',
#   '2088',
#   '1950',
#   '685',
#   '1092',
#   '4031',
#   '2731',
#   '5942',
#   '1483',
#   '31702',
#   '45630',
#   '112525',
#   '8554',
#   '8788',
#   '240',
#   '142',
#   '140',
#   '262',
#   '98',
#   '123',
#   '327',
#   '150',
#   '88',
#   '100',
#   '73717',
#   '1362',
#   '3076',
#   '7487',
#   '2994',
#   '8683',
#   '5466',
#   '2566',
#   '536',
#   '90431',
#   '1420',
#   '10275',
#   '1793',
#   '897',
#   '808',
#   '1619',
#   '1082',
#   '2247',
#   '1824',
#   '18773',
#   '65294',
#   '637',
#   '1842',
#   '4133',
#   '2378',
#   '1126',
#   '66181',
#   '23345',
#   '62158',
#   '45749',
#   '451382',
#   '218215',
#   '12858',
#   '17259',
#   '11091',
#   '39475',
#   '3091',
#   '9675',
#   '1310',
#   '765',
#   '3345',
#   '1103',
#   '4958',
#   '953',
#   '2054',
#   '673',
#   '794',
#   '1269',
#   '253',
#   '970',
#   '531',
#   '859',
#   '587',
#   '265',
#   '906',
#   '1682',
#   '1758',
#   '9295']}

# %% [markdown]
# ### Save as csv file

# %%
with open('data.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(videos.keys())
    writer.writerows(zip(*videos.values()))
# Out:
# 578
